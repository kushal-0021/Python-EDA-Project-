# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('Diwali_Sales_Data.csv', encoding='unicode_escape')

# %%
df.drop(['Status', 'unnamed1', 'User_ID'], axis = 1, inplace=True)

# %%
df
# Out:
#          Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0        Sanskriti  P00125942      F     26-35   28               0
# 1           Kartik  P00110942      F     26-35   35               1
# 2            Bindu  P00118542      F     26-35   35               1
# 3           Sudevi  P00237842      M      0-17   16               0
# 4             Joni  P00057942      M     26-35   28               1
# ...            ...        ...    ...       ...  ...             ...
# 11246      Manning  P00296942      M     18-25   19               1
# 11247  Reichenbach  P00171342      M     26-35   33               0
# 11248        Oshin  P00201342      F     36-45   40               0
# 11249       Noonan  P00059442      M     36-45   37               0
# 11250      Brumley  P00281742      F     18-25   19               0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
df.dropna(inplace=True, axis=0)

# %%
df.Orders.describe()
# Out:
# count    11239.000000
# mean         2.489634
# std          1.114967
# min          1.000000
# 25%          2.000000
# 50%          2.000000
# 75%          3.000000
# max          4.000000
# Name: Orders, dtype: float64

# %%
df["Marital_Status"] = df["Marital_Status"].astype(str)
df["Marital_Status"]
# Out:
# 0        0
# 1        1
# 2        1
# 3        0
# 4        1
#         ..
# 11246    1
# 11247    0
# 11248    0
# 11249    0
# 11250    0
# Name: Marital_Status, Length: 11239, dtype: object

# %%
df["Marital_Status"] = df["Marital_Status"].str.replace('0','Unmarried')

# %%
df["Marital_Status"]
# Out:
# 0        Unmarried
# 1                1
# 2                1
# 3        Unmarried
# 4                1
#            ...
# 11246            1
# 11247    Unmarried
# 11248    Unmarried
# 11249    Unmarried
# 11250    Unmarried
# Name: Marital_Status, Length: 11239, dtype: object

# %%
df["Marital_Status"] = df["Marital_Status"].str.replace('1','Married')
df["Marital_Status"]
# Out:
# 0        Unmarried
# 1          Married
# 2          Married
# 3        Unmarried
# 4          Married
#            ...
# 11246      Married
# 11247    Unmarried
# 11248    Unmarried
# 11249    Unmarried
# 11250    Unmarried
# Name: Marital_Status, Length: 11239, dtype: object

# %%
df.head()
# Out:
#    Cust_name Product_ID Gender Age Group  Age Marital_Status           State  \
# 0  Sanskriti  P00125942      F     26-35   28      Unmarried     Maharashtra
# 1     Kartik  P00110942      F     26-35   35        Married  Andhra Pradesh
# 2      Bindu  P00118542      F     26-35   35        Married   Uttar Pradesh
# 3     Sudevi  P00237842      M      0-17   16      Unmarried       Karnataka
# 4       Joni  P00057942      M     26-35   28        Married         Gujarat
#
#        Zone       Occupation Product_Category  Orders   Amount
# 0   Western       Healthcare             Auto       1  23952.0
# 1  Southern             Govt             Auto       3  23934.0
# 2   Central       Automobile             Auto       3  23924.0
# 3  Southern     Construction             Auto       2  23912.0
# 4   Western  Food Processing             Auto       2  23877.0

# %%
pd.unique(df['Age Group'])
# Out:
# array(['26-35', '0-17', '18-25', '51-55', '46-50', '55+', '36-45'],
#       dtype=object)

# %%
sns.barplot(x = 'Zone', y = 'Amount', data = df)
# Out:
# <Axes: xlabel='Zone', ylabel='Amount'>

# %%
pd.unique(df['State'])
# Out:
# array(['Maharashtra', 'Andhra\xa0Pradesh', 'Uttar Pradesh', 'Karnataka',
#        'Gujarat', 'Himachal Pradesh', 'Delhi', 'Jharkhand', 'Kerala',
#        'Haryana', 'Madhya Pradesh', 'Bihar', 'Rajasthan', 'Uttarakhand',
#        'Telangana', 'Punjab'], dtype=object)

# %%
sns.barplot(x = 'Gender', y = 'Amount', data = df)
#bar plot showing average expenditure of males and females
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %%
df["Amount"].describe()
# Out:
# count    11239.000000
# mean      9453.610858
# std       5222.355869
# min        188.000000
# 25%       5443.000000
# 50%       8109.000000
# 75%      12675.000000
# max      23952.000000
# Name: Amount, dtype: float64

# %%
sns.barplot(x = 'Zone', hue = 'Gender', y = 'Amount', data = df)
# Out:
# <Axes: xlabel='Zone', ylabel='Amount'>

# %%
df
# Out:
#          Cust_name Product_ID Gender Age Group  Age Marital_Status  \
# 0        Sanskriti  P00125942      F     26-35   28      Unmarried
# 1           Kartik  P00110942      F     26-35   35        Married
# 2            Bindu  P00118542      F     26-35   35        Married
# 3           Sudevi  P00237842      M      0-17   16      Unmarried
# 4             Joni  P00057942      M     26-35   28        Married
# ...            ...        ...    ...       ...  ...            ...
# 11246      Manning  P00296942      M     18-25   19        Married
# 11247  Reichenbach  P00171342      M     26-35   33      Unmarried
# 11248        Oshin  P00201342      F     36-45   40      Unmarried
# 11249       Noonan  P00059442      M     36-45   37      Unmarried
# 11250      Brumley  P00281742      F     18-25   19      Unmarried
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
sns.barplot(x = 'Marital_Status', y = 'Amount', data = df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %%
sns.barplot(x = 'Marital_Status', y = 'Amount', hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %%
sns.histplot(data = df, x = "Product_Category", kde = True, hue = "Age Group",bins=50)
# Out:
# <Axes: xlabel='Product_Category', ylabel='Count'>

# %% [markdown]
# # df["Product_Category"].unique()

# %%
sns.histplot(data = df, x = "Age Group", kde = True, hue = "Gender")
# Out:
# <Axes: xlabel='Age Group', ylabel='Count'>

# %%
sns.histplot(data = df, x = "Age Group", kde = True, hue = "Zone")
# Out:
# <Axes: xlabel='Age Group', ylabel='Count'>

# %%
palette_color = sns.color_palette('dark')
plt.pie(df["Amount"], labels=Product_Category, colors=palette_color, 
        explode= explode, autopct='%.0f%%')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 2
#       1 palette_color = sns.color_palette('dark')
# ----> 2 plt.pie(df["Amount"], labels=Product_Category, colors=palette_color,
#       3         explode= explode, autopct='%.0f%%')
#
# NameError: name 'Product_Category' is not defined

# %%
df
# Out:
#          Cust_name Product_ID Gender Age Group  Age Marital_Status  \
# 0        Sanskriti  P00125942      F     26-35   28      Unmarried
# 1           Kartik  P00110942      F     26-35   35        Married
# 2            Bindu  P00118542      F     26-35   35        Married
# 3           Sudevi  P00237842      M      0-17   16      Unmarried
# 4             Joni  P00057942      M     26-35   28        Married
# ...            ...        ...    ...       ...  ...            ...
# 11246      Manning  P00296942      M     18-25   19        Married
# 11247  Reichenbach  P00171342      M     26-35   33      Unmarried
# 11248        Oshin  P00201342      F     36-45   40      Unmarried
# 11249       Noonan  P00059442      M     36-45   37      Unmarried
# 11250      Brumley  P00281742      F     18-25   19      Unmarried
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
df["Product_Category"]
# Out:
# 0              Auto
# 1              Auto
# 2              Auto
# 3              Auto
# 4              Auto
#             ...
# 11246        Office
# 11247    Veterinary
# 11248        Office
# 11249        Office
# 11250        Office
# Name: Product_Category, Length: 11239, dtype: object

# %%
df
# Out:
#          Cust_name Product_ID Gender Age Group  Age Marital_Status  \
# 0        Sanskriti  P00125942      F     26-35   28      Unmarried
# 1           Kartik  P00110942      F     26-35   35        Married
# 2            Bindu  P00118542      F     26-35   35        Married
# 3           Sudevi  P00237842      M      0-17   16      Unmarried
# 4             Joni  P00057942      M     26-35   28        Married
# ...            ...        ...    ...       ...  ...            ...
# 11246      Manning  P00296942      M     18-25   19        Married
# 11247  Reichenbach  P00171342      M     26-35   33      Unmarried
# 11248        Oshin  P00201342      F     36-45   40      Unmarried
# 11249       Noonan  P00059442      M     36-45   37      Unmarried
# 11250      Brumley  P00281742      F     18-25   19      Unmarried
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
df["Orders"].unique()
# Out:
# array([1, 3, 2, 4], dtype=int64)

# %%
sns.histplot(data = df, x = "Orders", kde = True, hue = "Zone")
# Out:
# <Axes: xlabel='Orders', ylabel='Count'>

# %%
sns.histplot(data = df, x = "Orders", kde = True, hue = "Age Group")
# Out:
# <Axes: xlabel='Orders', ylabel='Count'>

# %%
df
# Out:
#          Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0        Sanskriti  P00125942      F     26-35   28               0
# 1           Kartik  P00110942      F     26-35   35               1
# 2            Bindu  P00118542      F     26-35   35               1
# 3           Sudevi  P00237842      M      0-17   16               0
# 4             Joni  P00057942      M     26-35   28               1
# ...            ...        ...    ...       ...  ...             ...
# 11246      Manning  P00296942      M     18-25   19               1
# 11247  Reichenbach  P00171342      M     26-35   33               0
# 11248        Oshin  P00201342      F     36-45   40               0
# 11249       Noonan  P00059442      M     36-45   37               0
# 11250      Brumley  P00281742      F     18-25   19               0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
df["Occupation"].unique()
# Out:
# array(['Healthcare', 'Govt', 'Automobile', 'Construction',
#        'Food Processing', 'Lawyer', 'Media', 'Banking', 'Retail',
#        'IT Sector', 'Aviation', 'Hospitality', 'Agriculture', 'Textile',
#        'Chemical'], dtype=object)

# %%
ax = sns.countplot(x = 'Gender', data = df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_gen = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

# %%
sns.barplot(x = 'Gender',y= 'Amount' ,data = sales_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %%
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Age Group',y= 'Amount' ,data = sales_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %%
sales_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Orders')
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
sales_state = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Amount')
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Occupation')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Occupation',y= 'Amount')
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Product_Category')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_Category',y= 'Amount')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %%
# CONCLUSION
#Married women age group 26-35 yrs from UP, Maharastra and Karnataka working in IT, Healthcare and Aviation are more likely to buy products from Food, Clothing and Electronics category3
